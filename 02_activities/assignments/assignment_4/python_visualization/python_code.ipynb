# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file using the provided path
file_path = 'C:/Users/Xiaoxiao/Downloads/Hospitalizations by vaccination status.csv'
data = pd.read_csv(file_path)

# Check the first few rows of the dataset
print(data.head())
# Out:
#    _id                 date  icu_unvac  icu_partial_vac  icu_full_vac  \
# 0    1  2021-08-10T00:00:00         22                3             0
# 1    2  2021-08-11T00:00:00         37                5             2
# 2    3  2021-08-12T00:00:00         45                5             2
# 3    4  2021-08-13T00:00:00         52                5             3
# 4    5  2021-08-14T00:00:00         53                4             1
#
#    hospitalnonicu_unvac  hospitalnonicu_partial_vac  hospitalnonicu_full_vac
# 0                    23                           4                       11
# 1                    34                           7                        8
# 2                    44                           7                        9
# 3                    65                           6                        8
# 4                    67                           6                       11

# %%
# Reconstruct the DataFrame for stacked_data
stacked_data = pd.DataFrame({
    'ICU': [total_icu['icu_unvac'], total_icu['icu_partial_vac'], total_icu['icu_full_vac']],
    'Non-ICU': [total_hospital_nonicu['hospitalnonicu_unvac'], 
                total_hospital_nonicu['hospitalnonicu_partial_vac'], 
                total_hospital_nonicu['hospitalnonicu_full_vac']]
}, index=['Unvaccinated', 'Partially Vaccinated', 'Fully Vaccinated'])

print("Reconstructed Stacked Data:")
print(stacked_data)
# Out:
# Reconstructed Stacked Data:
#                         ICU  Non-ICU
# Unvaccinated          22327    62540
# Partially Vaccinated   2310    12688
# Fully Vaccinated      19469   157728

# %%
# Add annotations for emphasis
stacked_data_percentage.T.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Proportion of Hospitalizations by Vaccination Status (Percentage)')
plt.ylabel('Percentage of Admissions')
plt.xlabel('Hospitalization Type')

# Adding annotations
plt.text(0, 70, "Higher proportion of\nUnvaccinated in ICU", color='red', fontsize=14)
plt.text(1, 20, "Higher proportion of\nFully Vaccinated in Non-ICU", color='red', fontsize=14)

plt.legend(title='Vaccination Status', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.savefig('hospitalizations_by_vaccination_status.png', dpi=300)
